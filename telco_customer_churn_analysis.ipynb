# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("/content/Telco_customer_churn.xlsx")

# %%
df
# Out:
#       CustomerID  Count  ...  CLTV                   Churn Reason
# 0     3668-QPYBK      1  ...  3239   Competitor made better offer
# 1     9237-HQITU      1  ...  2701                          Moved
# 2     9305-CDSKC      1  ...  5372                          Moved
# 3     7892-POOKP      1  ...  5003                          Moved
# 4     0280-XJGEX      1  ...  5340  Competitor had better devices
# ...          ...    ...  ...   ...                            ...
# 7038  2569-WGERO      1  ...  5306                            NaN
# 7039  6840-RESVB      1  ...  2140                            NaN
# 7040  2234-XADUH      1  ...  5560                            NaN
# 7041  4801-JZAZL      1  ...  2793                            NaN
# 7042  3186-AJIEK      1  ...  5097                            NaN
#
# [7043 rows x 33 columns]

# %%
df.shape
# Out:
# (7043, 33)

# %%
df['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Tenure Months'], bins=30, kde=True)
plt.xlabel('Tenure Months')
plt.ylabel('Customer count')
plt.title('Distribution of Tenure Months')
plt.show()

# %%
df['Tenure Months'].max()
df['Tenure Months'].min()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label',y='Tenure Months', data=df)
plt.xlabel('Churn Label')
plt.ylabel('tenure month')
plt.title('churn vs tenure month')
plt.show()

# %%
df['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df[df['Churn Label']=='Yes']
# Out:
#       CustomerID  Count  ...  CLTV                               Churn Reason
# 0     3668-QPYBK      1  ...  3239               Competitor made better offer
# 1     9237-HQITU      1  ...  2701                                      Moved
# 2     9305-CDSKC      1  ...  5372                                      Moved
# 3     7892-POOKP      1  ...  5003                                      Moved
# 4     0280-XJGEX      1  ...  5340              Competitor had better devices
# ...          ...    ...  ...   ...                                        ...
# 1864  1699-HPSBG      1  ...  4581  Competitor offered higher download speeds
# 1865  8775-CEBBJ      1  ...  2029  Competitor offered higher download speeds
# 1866  6894-LFHLY      1  ...  5571  Competitor offered higher download speeds
# 1867  0639-TSIQW      1  ...  5620               Competitor offered more data
# 1868  8361-LTMKD      1  ...  5839               Competitor offered more data
#
# [1869 rows x 33 columns]

# %%
df['Monthly Charges'].min()
# Out:
# 18.25

# %%
df['Monthly Charges'].max()
# Out:
# 118.75

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Churn Label',y='Tenure Months', data=df)
plt.xlabel('Churn Label')
plt.ylabel('month charges')
plt.title('churn vs tenure month')
plt.show()

# %%
df[df['Churn Label']=='Yes']['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64

# %%
df[df['Churn Label']=='No']['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    35.50
# 0.50    70.35
# 0.75    89.85
# Name: Monthly Charges, dtype: float64

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Contract', hue='Churn Label', data=df)
plt.xlabel('contract')
plt.ylabel('count')
plt.title('contract vs count')
plt.show()

# %%
df['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Internet Service', hue='Churn Label', data=df)
plt.xlabel('Internet Service')
plt.ylabel('count')
plt.title('Internet Service vs count')
plt.show()

# %%
df['Payment Method'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Payment Method', hue='Churn Label', data=df)
plt.xlabel('Payment Method')
plt.ylabel('count')
plt.title('Payment Method vs count')
plt.show()

# %%
df['Tech Support'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Tech Support', hue='Churn Label', data=df)
plt.xlabel('ech Support')
plt.ylabel('count')
plt.title('Tech Support vs count')
plt.show()

# %%
avg_tenure=df.groupby("Churn Label")['Tenure Months'].mean()
avg_tenure
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
print(avg_tenure)
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
numerical_cols=['Tenure Months','Monthly Charges','Churn Value','Churn Score','CLTV']

# %%
corr_mt=df[numerical_cols].corr()
corr_mt
# Out:
#                  Tenure Months  Monthly Charges  ...  Churn Score      CLTV
# Tenure Months         1.000000         0.247900  ...    -0.224987  0.396406
# Monthly Charges       0.247900         1.000000  ...     0.133754  0.098693
# Churn Value          -0.352229         0.193356  ...     0.664897 -0.127463
# Churn Score          -0.224987         0.133754  ...     1.000000 -0.079782
# CLTV                  0.396406         0.098693  ...    -0.079782  1.000000
#
# [5 rows x 5 columns]

# %%
sns.heatmap(corr_mt)
# Out:
# <Axes: >

# %%
contract_churn=pd.crosstab(df['Contract'],df['Churn Label'])
contract_churn
# Out:
# Churn Label       No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
contract_churn=pd.crosstab(df['Contract'],df['Churn Label'],normalize='index')
contract_churn
# Out:
# Churn Label           No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %%
tech_support_churn=pd.crosstab(df['Tech Support'],df['Churn Label'])
tech_support_churn
# Out:
# Churn Label            No   Yes
# Tech Support
# No                   2027  1446
# No internet service  1413   113
# Yes                  1734   310

# %% [markdown]
# Data Cleaning

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
df['Total Charges'].unique()
# Out:
# array([108.15, 151.65, 820.5, ..., 7362.9, 346.45, 6844.5], dtype=object)

# %%
df['Total Charges']=pd.to_numeric(df['Total Charges'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7032 non-null   float64
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(4), int64(6), object(23)
# memory usage: 1.8+ MB

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df[df['Total Charges'].isnull()]['Tenure Months']
# Out:
# 2234    0
# 2438    0
# 2568    0
# 2667    0
# 2856    0
# 4331    0
# 4687    0
# 5104    0
# 5719    0
# 6772    0
# 6840    0
# Name: Tenure Months, dtype: int64

# %%
df[df['Tenure Months']==0]
# Out:
#       CustomerID  Count        Country  ... Churn Score  CLTV  Churn Reason
# 2234  4472-LVYGI      1  United States  ...          36  2578           NaN
# 2438  3115-CZMZD      1  United States  ...          68  5504           NaN
# 2568  5709-LVOEQ      1  United States  ...          45  2048           NaN
# 2667  4367-NUYAO      1  United States  ...          48  4950           NaN
# 2856  1371-DWPAZ      1  United States  ...          30  4740           NaN
# 4331  7644-OMVMY      1  United States  ...          53  2019           NaN
# 4687  3213-VVOLG      1  United States  ...          49  2299           NaN
# 5104  2520-SGTTA      1  United States  ...          27  3763           NaN
# 5719  2923-ARZLG      1  United States  ...          69  4890           NaN
# 6772  4075-WKNIU      1  United States  ...          44  2342           NaN
# 6840  2775-SEFEE      1  United States  ...          65  5188           NaN
#
# [11 rows x 33 columns]

# %%
[7043-7032,(11/7043)]
# Out:
# [11, 0.001561834445548772]

# %%
df['Total Charges']=df['Total Charges'].fillna(0)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
drop_columns=['CustomerID','Count','Country','State','Zip Code','Lat long','Latitude','Longitude','Churn Label','Churn Score','CLTV','Churn Reason']

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   float64
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(4), int64(6), object(23)
# memory usage: 1.8+ MB

# %%
df['City'].unique()
# Out:
# array(['Los Angeles', 'Beverly Hills', 'Huntington Park', ..., 'Standish',
#        'Tulelake', 'Olympic Valley'], dtype=object)

# %%
df=df.drop(columns='City')

# %%
df['Churn Value'].unique()
# Out:
# array([1, 0])

# %%
df['Churn Value'].value_counts()
# Out:
# Churn Value
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
df_encoded=pd.get_dummies(df,drop_first=True)

# %%
df_encoded.head()
# Out:
#    Count  ...  Churn Reason_Service dissatisfaction
# 0      1  ...                                 False
# 1      1  ...                                 False
# 2      1  ...                                 False
# 3      1  ...                                 False
# 4      1  ...                                 False
#
# [5 rows x 8750 columns]

# %%
df_encoded.shape
# Out:
# (7043, 8750)

# %%
df_encoded.columns
# Out:
# Index(['Count', 'Zip Code', 'Latitude', 'Longitude', 'Tenure Months',
#        'Monthly Charges', 'Total Charges', 'Churn Value', 'Churn Score',
#        'CLTV',
#        ...
#        'Churn Reason_Lack of self-service on Website',
#        'Churn Reason_Limited range of services',
#        'Churn Reason_Long distance charges', 'Churn Reason_Moved',
#        'Churn Reason_Network reliability',
#        'Churn Reason_Poor expertise of online support',
#        'Churn Reason_Poor expertise of phone support',
#        'Churn Reason_Price too high', 'Churn Reason_Product dissatisfaction',
#        'Churn Reason_Service dissatisfaction'],
#       dtype='object', length=8750)

# %%
X=df_encoded.drop(columns=['Churn Value'])
y=df_encoded['Churn Value']

# %%
X.shape,y.shape
# Out:
# ((7043, 8749), (7043,))

# %%
df['Churn Value'].value_counts()
# Out:
# Churn Value
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
# X.info()
(5174/7043)*100,(1869/7043)*100
# Out:
# (73.4630129206304, 26.536987079369588)

# %%
print(y)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Value, Length: 7043, dtype: int64

# %%
X=df_encoded.drop('Churn Value',axis=1)
Y=df_encoded['Churn Value']

# %%
X.shape
Y.shape
# Out:
# (7043,)

# %%
print(X)
# Out:
#       Count  ...  Churn Reason_Service dissatisfaction
# 0         1  ...                                 False
# 1         1  ...                                 False
# 2         1  ...                                 False
# 3         1  ...                                 False
# 4         1  ...                                 False
# ...     ...  ...                                   ...
# 7038      1  ...                                 False
# 7039      1  ...                                 False
# 7040      1  ...                                 False
# 7041      1  ...                                 False
# 7042      1  ...                                 False
#
# [7043 rows x 8749 columns]

# %% [markdown]
# **Machine learning impletation**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train.shape,X_test ,y_train.shape ,y_test.shape
# Out:
# ((5634, 8749),
#        Count  ...  Churn Reason_Service dissatisfaction
#  185       1  ...                                 False
#  2715      1  ...                                 False
#  3825      1  ...                                 False
#  1807      1  ...                                 False
#  132       1  ...                                  True
#  ...     ...  ...                                   ...
#  6366      1  ...                                 False
#  315       1  ...                                 False
#  2439      1  ...                                 False
#  5002      1  ...                                 False
#  1161      1  ...                                 False
#
#  [1409 rows x 8749 columns],
#  (5634,),
#  (1409,))

# %%
X_train.shape
# Out:
# (5634, 8749)

# %%
X_test.shape
# Out:
# (1409, 8749)

# %%
y_train.shape
# Out:
# (5634,)

# %%
y_test.shape
# Out:
# (1409,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=rf_model.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %%
y_test
# Out:
# 185     1
# 2715    0
# 3825    0
# 1807    1
# 132     1
#        ..
# 6366    0
# 315     1
# 2439    0
# 5002    0
# 1161    1
# Name: Churn Value, Length: 1409, dtype: int64

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9971611071682044

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[1009    0]
#  [   4  396]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1009
#            1       1.00      0.99      0.99       400
#
#     accuracy                           1.00      1409
#    macro avg       1.00      0.99      1.00      1409
# weighted avg       1.00      1.00      1.00      1409

# %% [markdown]
# **Approach 1 - Handle class imbalance**

# %%
rf_balanced=RandomForestClassifier(n_estimators=100,random_state=42,class_weight='balanced')
rf_balanced.fit(X_train,y_train)
y_pred_balanced=rf_balanced.predict(X_test)
accuracy_balanced=accuracy_score(y_test,y_pred_balanced)
cm_balanced=confusion_matrix(y_test,y_pred_balanced)
print(accuracy_balanced,cm_balanced)
print(classification_report(y_test,y_pred_balanced))
# Out:
# 0.9964513839602555 [[1009    0]
#  [   5  395]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1009
#            1       1.00      0.99      0.99       400
#
#     accuracy                           1.00      1409
#    macro avg       1.00      0.99      1.00      1409
# weighted avg       1.00      1.00      1.00      1409

# %% [markdown]
# **Approach 2 hyperparameter tuning**

# %%
rf_tuned=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
rf_tuned.fit(X_train,y_train)
y_pred_tuned=rf_tuned.predict(X_test)

print(classification_report(y_test,y_pred_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      1009
#            1       0.93      0.95      0.94       400
#
#     accuracy                           0.97      1409
#    macro avg       0.95      0.96      0.96      1409
# weighted avg       0.97      0.97      0.97      1409

# %% [markdown]
# **Approach 3 Feature analysis**

# %%
import pandas as pd
feature_importance =pd.DataFrame({
    'Feature':X.columns,
    'Importance':rf_tuned.feature_importances_
})
feature_importance =feature_importance.sort_values(by='Importance',ascending=False)
print(feature_importance)
# Out:
#                            Feature  Importance
# 8729               Churn Label_Yes    0.154238
# 7                      Churn Score    0.082715
# 8724             Contract_Two year    0.040298
# 4                    Tenure Months    0.036975
# 8709  Internet Service_Fiber optic    0.033607
# ...                            ...         ...
# 4819         CustomerID_6769-DYBQN    0.000000
# 4786         CustomerID_6726-NNFWD    0.000000
# 4785         CustomerID_6725-TPKJO    0.000000
# 4784         CustomerID_6723-WSNTY    0.000000
# 4800         CustomerID_6734-GMPVK    0.000000
#
# [8749 rows x 2 columns]

# %%
print(feature_importance .tail(15))
# Out:
#                     Feature  Importance
# 4802  CustomerID_6734-PSBAW         0.0
# 4801  CustomerID_6734-JDTTV         0.0
# 4783  CustomerID_6723-CEGQI         0.0
# 4799  CustomerID_6734-FQAJX         0.0
# 4798  CustomerID_6734-CKRSM         0.0
# 4797  CustomerID_6733-LRIZX         0.0
# 4828  CustomerID_6778-EICRF         0.0
# 4825  CustomerID_6773-LQTVT         0.0
# 4824  CustomerID_6772-WFQRD         0.0
# 4820  CustomerID_6770-UAYGJ         0.0
# 4819  CustomerID_6769-DYBQN         0.0
# 4786  CustomerID_6726-NNFWD         0.0
# 4785  CustomerID_6725-TPKJO         0.0
# 4784  CustomerID_6723-WSNTY         0.0
# 4800  CustomerID_6734-GMPVK         0.0

# %%
X_selected=X.drop(['Phone Service_Yes' , 'Multiple Lines_No phone service'],axis=1)

# %%
X_train_sel, X_test_sel, Y_train_sel, Y_test_sel = train_test_split(
    X_selected, Y, test_size=0.2, random_state=42)

# %%
rf_selected=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
rf_selected.fit(X_train_sel, Y_train_sel)
y_pred_selected=rf_selected.predict(X_test_sel)

print(classification_report(Y_test_sel,y_pred_selected))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95      1009
#            1       0.82      0.94      0.88       400
#
#     accuracy                           0.93      1409
#    macro avg       0.90      0.93      0.91      1409
# weighted avg       0.93      0.93      0.93      1409

# %% [markdown]
# **Approach combination of trees and depth**

# %%
from sklearn.metrics import accuracy_score, recall_score

n_estimators_lists = [100, 200, 300, 400, 500]
max_depth_lists = [5, 10, 15, 20]
results = []

for n_trees in n_estimators_lists:
    for depth in max_depth_lists:
        rf = RandomForestClassifier(n_estimators=n_trees, max_depth=depth, random_state=42, class_weight='balanced')
        rf.fit(X_train, y_train)
        y_pred_tuned = rf.predict(X_test)

        accuracy = accuracy_score(y_test, y_pred_tuned)
        recall = recall_score(y_test, y_pred_tuned)

        results.append({
            'n_estimators': n_trees,
            'max_depth': depth,
            'accuracy': accuracy,
            'recall': recall
        })

results_df = pd.DataFrame(results)
print(results_df.sort_values(by='recall', ascending=False).head())
# Out:
#     n_estimators  max_depth  accuracy  recall
# 15           400         20  0.987935  0.9875
# 19           500         20  0.987225  0.9875
# 7            200         20  0.984386  0.9875
# 3            100         20  0.981547  0.9850
# 11           300         20  0.987225  0.9825

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

n_estimators_list = [100, 200, 300, 400, 500]
max_depth_list = [5, 10, 15, 20]
results = []

for n_trees in n_estimators_list:
    for depth in max_depth_list:
        rf = RandomForestClassifier(n_estimators=n_trees, max_depth=depth, random_state=42, class_weight='balanced')
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)

        accuracy = accuracy_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results.append({
            'Trees': n_trees,
            'Depth': depth,
            'Accuracy': accuracy,
            'Recall': recall,
            'Precision': precision,
            'F1 Score': f1
        })

result_df = pd.DataFrame(results)
result_df = result_df.sort_values(by=['Recall', 'Accuracy'], ascending=False)
print(result_df.head(20))
# Out:
#     Trees  Depth  Accuracy  Recall  Precision  F1 Score
# 15    400     20  0.987935  0.9875   0.970516  0.978934
# 19    500     20  0.987225  0.9875   0.968137  0.977723
# 7     200     20  0.984386  0.9875   0.958738  0.972906
# 3     100     20  0.981547  0.9850   0.951691  0.968059
# 11    300     20  0.987225  0.9825   0.972772  0.977612
# 2     100     15  0.973740  0.9800   0.931116  0.954933
# 10    300     15  0.968772  0.9750   0.919811  0.946602
# 6     200     15  0.967353  0.9750   0.915493  0.944310
# 18    500     15  0.969482  0.9725   0.923990  0.947625
# 14    400     15  0.971611  0.9675   0.934783  0.950860
# 17    500     10  0.962385  0.9600   0.912114  0.935445
# 1     100     10  0.971611  0.9550   0.945545  0.950249
# 9     300     10  0.965224  0.9525   0.927007  0.939581
# 13    400     10  0.961675  0.9525   0.915865  0.933824
# 4     200      5  0.927608  0.9525   0.821121  0.881944
# 5     200     10  0.958836  0.9475   0.911058  0.928922
# 8     300      5  0.936835  0.9475   0.847875  0.894923
# 16    500      5  0.944642  0.9450   0.870968  0.906475
# 0     100      5  0.908446  0.9450   0.779381  0.854237
# 12    400      5  0.936835  0.9425   0.851016  0.894425

# %%
from sklearn.model_selection import cross_val_score
final_rf=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')

# %%
cv_accuracy=cross_val_score(final_rf,X,Y,cv=5,scoring='accuracy')

# %%
cv_recall=cross_val_score(final_rf,X,Y,cv=5,scoring='recall')

# %%
cv_recall.mean()
# Out:
# np.float64(0.9486344281802411)

# %% [markdown]
# **OPTIONAL**

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
import matplotlib.pyplot as plt

# %%
y_prob1=rf_model.predict_proba(X)

# %%
y_prob=rf_tuned.predict_proba(X)

# %%
churn_prob=y_prob[:,1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
y_prob_corrected = rf_tuned.predict_proba(X_test)
churn_prob_corrected = y_prob_corrected[:, 1]
fpr,tpr,thresholds=roc_curve(y_test,churn_prob_corrected)
auc_score=roc_auc_score(y_test,churn_prob_corrected)
print(auc_score)
# Out:
# 0.9922571853320119

# %%
churn_prob= y_prob[:,1]

# %% [markdown]
# **CUSTOMER SEGMENTATION**

# %%
segmentation_data=pd.DataFrame({
    'Tenure Months' :X['Tenure Months'],
    'Monthly Charges' :X['Monthly Charges'],
    'Total Charges':X['Total Charges'],
    'Churn Probability' :churn_prob})

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 0                 2            53.85         108.15           0.651436
# 1                 2            70.70         151.65           0.709954
# 2                 8            99.65         820.50           0.679578
# 3                28           104.80        3046.05           0.636755
# 4                49           103.70        5036.30           0.621367
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40           0.215905
# 7039             24            84.80        1990.50           0.321536
# 7040             72           103.20        7362.90           0.387242
# 7041             11            29.60         346.45           0.385107
# 7042             66           105.65        6844.50           0.362600
#
# [7043 rows x 4 columns]

# %% [markdown]
# **Impletation of knodes**

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()

# %%
scaled_data=scalar.fit_transform(segmentation_data)
print(scaled_data[:5])
# Out:
# [[-1.23672422 -0.36266036 -0.9580659   1.42557162]
#  [-1.23672422  0.19736523 -0.93887444  1.79320755]
#  [-0.99240204  1.1595457  -0.64378925  1.60237077]
#  [-0.17799476  1.33071079  0.3380854   1.33333873]
#  [ 0.67713287  1.29415125  1.2161497   1.23666784]]

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
  kmeans=KMeans(n_clusters=i,random_state=42, n_init=10)
  kmeans.fit(scaled_data)
  wcss.append(kmeans.inertia_)
plt.figure(figsize=(8,6))
plt.plot(range(1,11),wcss,marker='o')
plt.xlabel('Number of Clusters K')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
kmeans=KMeans(n_clusters=3, random_state=42)

# %%
clusters = kmeans.fit_predict(scaled_data)

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 0                 2            53.85         108.15           0.651436
# 1                 2            70.70         151.65           0.709954
# 2                 8            99.65         820.50           0.679578
# 3                28           104.80        3046.05           0.636755
# 4                49           103.70        5036.30           0.621367
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40           0.215905
# 7039             24            84.80        1990.50           0.321536
# 7040             72           103.20        7362.90           0.387242
# 7041             11            29.60         346.45           0.385107
# 7042             66           105.65        6844.50           0.362600
#
# [7043 rows x 4 columns]

# %%
segmentation_data['Cluster']=clusters

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  Cluster
# 0                 2            53.85         108.15           0.651436        2
# 1                 2            70.70         151.65           0.709954        2
# 2                 8            99.65         820.50           0.679578        2
# 3                28           104.80        3046.05           0.636755        2
# 4                49           103.70        5036.30           0.621367        0
# ...             ...              ...            ...                ...      ...
# 7038             72            21.15        1419.40           0.215905        1
# 7039             24            84.80        1990.50           0.321536        2
# 7040             72           103.20        7362.90           0.387242        0
# 7041             11            29.60         346.45           0.385107        1
# 7042             66           105.65        6844.50           0.362600        0
#
# [7043 rows x 5 columns]

# %%
cluster_summary=segmentation_data.copy()

# %%
cluster_summary['Cluster'] = clusters
cluster_summary.groupby('Cluster').mean()
# Out:
#          Tenure Months  Monthly Charges  Total Charges  Churn Probability
# Cluster
# 0            57.967338        89.607718    5192.119955           0.391624
# 1            30.069643        29.780357     899.227254           0.284920
# 2            12.101636        73.650837     949.186741           0.574924

# %%
cluster_summary
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  Cluster
# 0                 2            53.85         108.15           0.651436        2
# 1                 2            70.70         151.65           0.709954        2
# 2                 8            99.65         820.50           0.679578        2
# 3                28           104.80        3046.05           0.636755        2
# 4                49           103.70        5036.30           0.621367        0
# ...             ...              ...            ...                ...      ...
# 7038             72            21.15        1419.40           0.215905        1
# 7039             24            84.80        1990.50           0.321536        2
# 7040             72           103.20        7362.90           0.387242        0
# 7041             11            29.60         346.45           0.385107        1
# 7042             66           105.65        6844.50           0.362600        0
#
# [7043 rows x 5 columns]

# %%
cluster_names= {
0:'Budget Loyal Customer',
1:'High Risk New Customer',
2:'Loyal Premium Customer'

}

# %%
cluster_summary['Cluster_Segment'] = cluster_summary['Cluster'].map(cluster_names)

# %%
plt.figure(figsize=(10, 8))

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Monthly Charges', y='Monthly Charges', hue='Cluster_Segment',data=cluster_summary, palette='Spectral')
# Out:
# <Axes: xlabel='Monthly Charges', ylabel='Monthly Charges'>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Tenure Months', y='Monthly Charges', hue='Cluster_Segment',data=cluster_summary, palette='Spectral')
# Out:
# <Axes: xlabel='Tenure Months', ylabel='Monthly Charges'>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Total Charges', y='Monthly Charges', hue='Cluster_Segment',data=cluster_summary, palette='Spectral')
# Out:
# <Axes: xlabel='Total Charges', ylabel='Monthly Charges'>
